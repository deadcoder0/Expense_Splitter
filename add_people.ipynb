# %%
def create_group():

    label = input("Please create a group name (Hint: Use a household name or trip destination.)")

    if not label.isalpha():
        print ("Error! Only letters a-z allowed!")

   
    elif len(label) > 10:
        print ("Error! Only 10 characters allowed!")
    


       

    print(f"Your input was: {label}")
    return label

# %%
create_group()
# Out:
# Your input was: stockholm
# 'stockholm'

# %%
def group_size_confirm():


    number_of_members = input("Please enter the number of people in your group")

    if not number_of_members.isnumeric():
        print ("Error! Only numbers 1 -9 are allowed!")

    return number_of_members

# %%
def add_people():

    person = input("Please provide name: ")
   
    if not person.isalpha():
        print ("Error! Only letters a-z allowed!")

    elif len(person) > 10:
        print ("Error! Only 10 characters allowed!")
    
    while len(number_of_members) < input:
        add_people



    print(f"Your input was: {person}")
    return person

# %%
person = add_people()
# Out:
# Your input was: lisa

# %%
person
# Out:
# 'lisa'

# %%
group
# Out:
# []

# %%
def add_expense():

    amount = input("Please provide an amount: ")

    if not amount.isnumeric():
        print ("Error! Only numbers are allowed!")


    print(f"Your input was: {amount}")

# %%
add_expense()
# Out:
# Your input was: 120000

# %%
#people = {}

#if name in people:
#print("Person already exists")
#return


#people[name] = 0
#print(f"{name} added.")
